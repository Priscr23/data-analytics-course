# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install matplotlib

# %%
path = "C:/Users/prisc/apps/data-analytics-course/data/raw/tested.data"
df =pd.read_csv(path, header=None)
df.columns = ["Passenger_#", "Survivor", "P_class", "Name", "Sex","Age", "#_siblings", "Parch", "Ticket", "Fare","Cabin","Embarked"]
df
# Out:
#      Passenger_#  Survivor P_class                              Name     Sex  \
# 0    PassengerId  Survived  Pclass                              Name     Sex
# 1            892         0       3                  Kelly, Mr. James    male
# 2            893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 3            894         0       2         Myles, Mr. Thomas Francis    male
# 4            895         0       3                  Wirz, Mr. Albert    male
# ..           ...       ...     ...                               ...     ...
# 414         1305         0       3                Spector, Mr. Woolf    male
# 415         1306         1       1      Oliva y Ocana, Dona. Fermina  female
# 416         1307         0       3      Saether, Mr. Simon Sivertsen    male
# 417         1308         0       3               Ware, Mr. Frederick    male
# 418         1309         0       3          Peter, Master. Michael J    male
#
# ...

# %%
df["Passenger_#"] = df["Passenger_#"].astype(str)# Convertir la columna "Passenger_#" a tipo string
df = df[df["Passenger_#"].str.isdigit()]# Eliminar filas donde el valor de "Passenger_#" no es un número
df["Passenger_#"] = df["Passenger_#"].astype(int)# Convertir la columna "Passenger_#" a tipo entero
df["Passenger_#"].plot(kind="hist")
plt.show()

# %% [markdown]
# Hallazgo de passanger number: se les asignaba un número a cada pasajero, se muestra que mayormente los números eran de 1300 o mayor.

# %%
df["Survivor"] = df["Survivor"].astype(str)# Convertir la columna "Passenger_#" a tipo string
df = df[df["Survivor"].str.isdigit()]# Eliminar filas donde el valor de "Passenger_#" no es un número
df["Survivor"] = df["Survivor"].astype(int)# Convertir la columna "Passenger_#" a tipo entero
df["Survivor"].plot(kind="hist")
plt.show()

# %% [markdown]
# Hallazgo de sobrevivientes: siendo 0 no sobreviviente y 1 sobreviviente, mostrando que hubo menos sobrevivientes con una gran diferencia de los sobrevivientes.

# %%
df["P_class"] = df["P_class"].astype(str)# Convertir la columna "Passenger_#" a tipo string
df = df[df["P_class"].str.isdigit()]# Eliminar filas donde el valor de "Passenger_#" no es un número
df["P_class"] = df["P_class"].astype(int)# Convertir la columna "Passenger_#" a tipo entero
df["P_class"].plot(kind="hist")
plt.show()

# %% [markdown]
# Hallazgo de clase social: siendo 1 primera clase, 2 clase media y 3 tercera clase.
# Como muestra el gráfico sobre sale la tercera clase que era la que abordaba en el barco, siguiendole por primera, y por último clase media. Aunque en realidad era primero la tercera, luego segunda y por último primera, ya que hay datos faltantes.

# %%
df["Age"] = df["Age"].astype(str)# Convertir la columna "Passenger_#" a tipo string
df = df[df["Age"].str.isdigit()]# Eliminar filas donde el valor de "Passenger_#" no es un número
df["Age"] = df["Age"].astype(int)# Convertir la columna "Passenger_#" a tipo entero
df["Age"].plot(kind="hist")
plt.show()

# %%
df["#_siblings"] = df["#_siblings"].astype(str)# Convertir la columna "Passenger_#" a tipo string
df = df[df["#_siblings"].str.isdigit()]# Eliminar filas donde el valor de "Passenger_#" no es un número
df["#_siblings"] = df["#_siblings"].astype(int)# Convertir la columna "Passenger_#" a tipo entero
df["#_siblings"].plot(kind="hist")
plt.show()

# %%
df["Parch"] = df["Parch"].astype(str)# Convertir la columna "Passenger_#" a tipo string
df = df[df["Parch"].str.isdigit()]# Eliminar filas donde el valor de "Passenger_#" no es un número
df["Parch"] = df["Parch"].astype(int)# Convertir la columna "Passenger_#" a tipo entero
df["Parch"].plot(kind="hist")
plt.show()

# %%
df["Ticket"] = df["Ticket"].astype(str)# Convertir la columna "Passenger_#" a tipo string
df = df[df["Ticket"].str.isdigit()]# Eliminar filas donde el valor de "Passenger_#" no es un número
df["Ticket"] = df["Ticket"].astype(int)# Convertir la columna "Passenger_#" a tipo entero
df["Ticket"].plot(kind="hist")
plt.show()

# %%
df["Fare"] = df["Fare"].astype(str)
df = df[df["Fare"].str.isdigit()]
df["Fare"] = df["Fare"].astype(float) 
df["Fare"].plot(kind="hist")
plt.show()

# %%
name_counts = df['Name'].value_counts()
name_counts.plot(kind='pie', figsize=(9, 9))
plt.title('Names')
plt.ylabel('')
plt.show()

# %%
name_counts = df['Sex'].value_counts()
name_counts.plot(kind='pie', figsize=(9, 9))
plt.title('Gender')
plt.ylabel('')
plt.show()

# %%
name_counts = df['Cabin'].value_counts()
name_counts.plot(kind='pie', figsize=(9, 9))
plt.title('Cabin')
plt.ylabel('')
plt.show()

# %%
name_counts = df['Embarked'].value_counts()
name_counts.plot(kind='pie', figsize=(9, 9))
plt.title('Embarked')
plt.ylabel('')
plt.show()

# %%
import seaborn as sns

sns.pairplot(df, hue="Sex")
